# %%
from datetime import datetime

data = [["02-2018", 131824.6970378884], ["03-2018", 156143.78560509396], ["09-2015", 100034.66822588533], ["12-2015", 202883.632316504], ["08-2015", 72940.21712670397], ["10-2015", 124934.01908849277], ["04-2017", 156839.67702323574], ["09-2017", 146346.28332376023], ["07-2016", 114353.3291824716], ["11-2017", 146613.7212948582], ["04-2016", 95096.54076645788], ["06-2016", 130125.45646212902], ["11-2016", 118474.20698056064], ["01-2017", 144585.8323444452], ["01-2018", 102167.12354317823], ["12-2016", 134463.8302327048], ["03-2016", 103583.61174482375], ["04-2018", 236640.05872251868], ["10-2018", 202532.2626962209], ["11-2018", 224208.95181702235], ["12-2018", 228197.0665342265], ["10-2017", 139834.0791119676], ["02-2017", 185771.26611789103], ["01-2016", 140463.7812759377], ["08-2016", 120120.0512198887], ["08-2018", 185842.0453268484], ["07-2017", 132832.13221663184], ["05-2016", 119736.31386713355], ["10-2016", 117086.93197563328], ["05-2018", 148892.9915448342], ["09-2018", 202253.99873822473], ["03-2017", 147214.03904270852], ["09-2016", 139579.05819828573], ["11-2015", 209520.94340378218], ["05-2017", 152468.92858418153], ["12-2017", 125341.02766114203], ["06-2018", 180876.6369936829], ["02-2016", 130175.52141758327], ["07-2018", 160844.2135075465], ["08-2017", 139554.8957560159], ["06-2017", 129431.8443809003], ["01-2019", 239351.72778974313]]

# Convert date strings to datetime objects
data = [(datetime.strptime(date, '%m-%Y'), value) for date, value in data]

# Sort data by date
data = sorted(data)

# Convert back to original format
data = [([date.strftime('%m-%Y'), value]) for date, value in data]

# %%
import matplotlib.pyplot as plt

dates = [date for date, value in data]
values = [value for date, value in data]

plt.bar(dates, values)
plt.xticks(rotation=90)
plt.show()
