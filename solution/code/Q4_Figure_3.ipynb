# %%
from datetime import datetime

data = [["02-2018", 23636574203.828968], ["03-2018", 15549765961.743279], ["09-2015", 56511301521.033226], ["12-2015", 55899526672.35486], ["08-2015", 159744029578.0331], ["10-2015", 53901692120.53661], ["04-2017", 22355124545.395313], ["09-2017", 30675032016.98866], ["07-2016", 22629542449.24175], ["11-2017", 15312465314.693544], ["04-2016", 23361180502.721268], ["06-2016", 23021251389.812138], ["11-2016", 24634294365.279957], ["01-2017", 22507570807.719795], ["01-2018", 52106060636.84506], ["12-2016", 50318068074.68645], ["03-2016", 32797039087.356663], ["04-2018", 13153739247.92998], ["10-2018", 14526936383.350004], ["11-2018", 16034859008.681648], ["12-2018", 16338844844.01464], ["10-2017", 17498286426.76893], ["02-2017", 23047230327.254303], ["01-2016", 56596270931.31685], ["08-2016", 22396836435.95849], ["08-2018", 18483235826.894577], ["07-2017", 25460300456.232983], ["05-2016", 23746277028.263245], ["10-2016", 32112869584.91467], ["05-2018", 17422505108.98642], ["09-2018", 15213870989.523382], ["03-2017", 23232253600.81683], ["09-2016", 25270403393.62608], ["11-2015", 53607614201.796776], ["05-2017", 23572314972.015255], ["12-2017", 33439362876.10833], ["06-2018", 16533308366.813026], ["02-2016", 69180681134.38847], ["07-2018", 27506077453.154324], ["08-2017", 25905774673.990234], ["06-2017", 30199442465.128716], ["01-2019", 13954460713.077589]]

# Convert date strings to datetime objects
data = [(datetime.strptime(date, '%m-%Y'), value) for date, value in data]

# Sort data by date
data = sorted(data)

# Convert back to original format
data = [([date.strftime('%m-%Y'), value]) for date, value in data]

# %%
import matplotlib.pyplot as plt

dates = [date for date, value in data]
values = [value for date, value in data]

plt.bar(dates, values)
plt.xticks(rotation=90)
plt.show()
