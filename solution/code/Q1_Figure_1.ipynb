# %% [markdown]
# Plotting the graph from the obtained data

# %%
from datetime import datetime

data = [["02-2018", 22231978], ["03-2018", 20261862], ["09-2015", 173805], ["12-2015", 347092], ["08-2015", 85609], ["10-2015", 205045], ["04-2017", 2539966], ["09-2017", 10679242], ["07-2016", 1356907], ["11-2017", 15292269], ["04-2016", 1023096], ["06-2016", 1351536], ["11-2016", 1301586], ["01-2017", 1409664], ["01-2018", 33504270], ["12-2016", 1316131], ["03-2016", 917170], ["04-2018", 20876642], ["10-2018", 17056926], ["11-2018", 16713911], ["12-2018", 17107601], ["10-2017", 12602063], ["02-2017", 1410048], ["01-2016", 404816], ["08-2016", 1405743], ["08-2018", 19842059], ["07-2017", 7835875], ["05-2016", 1346796], ["10-2016", 1329847], ["05-2018", 25105717], ["09-2018", 16056742], ["03-2017", 2426471], ["09-2016", 1387412], ["11-2015", 234733], ["05-2017", 4245516], ["12-2017", 26732085], ["06-2018", 22471788], ["02-2016", 520040], ["07-2018", 19937033], ["08-2017", 10523178], ["06-2017", 7244657], ["01-2019", 1002431]]

# Converting date strings to datetime objects
data = [(datetime.strptime(date, '%m-%Y'), value) for date, value in data]

# Sorting data by date
data = sorted(data)

# Converting back to original format
data = [([date.strftime('%m-%Y'), value]) for date, value in data]

# %%
import matplotlib.pyplot as plt

dates = [date for date, value in data]
values = [value for date, value in data]

plt.bar(dates, values)
plt.xticks(rotation=90)
plt.show()
